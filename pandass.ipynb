# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['ashu','adi','arrush','ruhani','suhani'],
    "marks":[100,99,98,33,64],
    "city":['mohali','mohali','dehradun','solan','solan']
}

# %%
df=pd.DataFrame(dict1) #it would create a table frame of my dictnonary

# %%
df
# Out:
#      name  marks      city
# 0    ashu    100    mohali
# 1     adi     99    mohali
# 2  arrush     98  dehradun
# 3  ruhani     33     solan
# 4  suhani     64     solan

# %%
df.to_csv('siblings.csv') #to convert it to exel file

# %%
df.to_csv('siblings_no_index.csv',index=False) #to convert it to exel file with out index

# %%
df.head(2)#it would display first 2 elements of dictonanry
# Out:
#    name  marks    city
# 0  ashu    100  mohali
# 1   adi     99  mohali

# %%
df.tail(2)#it would display last 2 element of dictonanry
# Out:
#      name  marks   city
# 3  ruhani     33  solan
# 4  suhani     64  solan

# %%
df.describe() #it would give all statical analysis of the numerical column of the dictonary
# Out:
#             marks
# count    5.000000
# mean    78.800000
# std     29.760712
# min     33.000000
# 25%     64.000000
# 50%     98.000000
# 75%     99.000000
# max    100.000000

# %%
singer=pd.read_csv('singer.csv') # to read a cvs file using pandas

# %%
singer
# Out:
#        SINGER  Albums  ratings
# 0  Babbu mann      12      5.0
# 1      Sharry       5      4.5
# 2       Garry       3      4.1
# 3       Sidhu       2      4.0
# 4       Honey       6      4.7

# %%
singer['SINGER']#to get the data of a perticular column
# Out:
# 0    Babbu mann
# 1        Sharry
# 2         Garry
# 3         Sidhu
# 4         Honey
# Name: SINGER, dtype: object

# %%
singer['SINGER'][2] # TO PICK UP a specific element from  column
# Out:
# 'Garry'

# %%
singer['SINGER'][1]='Sharry Mann'#to change th e value of an element in a column
singer['SINGER'][2]='Garry Sandhu'
singer['SINGER'][3]='Sidhu Mossewala'
singer['SINGER'][4]='Honey Singh'
# Out:
# <ipython-input-14-d3552ef147f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   singer['SINGER'][1]='Sharry Mann'#to change th e value of an element in a column
# <ipython-input-14-d3552ef147f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   singer['SINGER'][2]='Garry Sandhu'
# <ipython-input-14-d3552ef147f1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   singer['SINGER'][3]='Sidhu Mossewala'
# ...

# %%
singer
# Out:
#             SINGER  Albums  ratings
# 0       Babbu mann      12      5.0
# 1      Sharry Mann       5      4.5
# 2     Garry Sandhu       3      4.1
# 3  Sidhu Mossewala       2      4.0
# 4      Honey Singh       6      4.7

# %%
singer.index=['pehli','duji','thiji','chowthi','panjvi']

# %%
singer
# Out:
#                   SINGER  Albums  ratings
# pehli         Babbu mann      12      5.0
# duji         Sharry Mann       5      4.5
# thiji       Garry Sandhu       3      4.1
# chowthi  Sidhu Mossewala       2      4.0
# panjvi       Honey Singh       6      4.7

# %%
ser=pd.Series(np.random.rand(34)) #it would create a random series of 0-33

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser
# Out:
# 0     0.248021
# 1     0.540265
# 2     0.125629
# 3     0.628104
# 4     0.370623
# 5     0.833412
# 6     0.842221
# 7     0.775221
# 8     0.943731
# 9     0.368282
# 10    0.271080
# 11    0.282773
# 12    0.082377
# 13    0.936238
# 14    0.035288
# 15    0.573318
# 16    0.030876
# 17    0.445597
# 18    0.885034
# 19    0.344387
# 20    0.189937
# 21    0.857495
# 22    0.751124
# 23    0.305679
# 24    0.562240
# 25    0.817553
# 26    0.189697
# 27    0.395258
# 28    0.434562
# 29    0.865690
# 30    0.593066
# 31    0.696733
# 32    0.146170
# 33    0.726754
# dtype: float64

# %%
newf=pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newf
# Out:
#             0         1         2         3         4
# 0    0
# 1    1234.000000  0.863090  0.906042  0.095743  0.838045        NaN
# 2       0.170044  0.295632  0.110376  0.090735  0.868596        NaN
# 3       0.344054  0.172476  0.538477  0.322482  0.026525        NaN
# 4       0.807891  0.169485  0.310786  0.950250  0.877985        NaN
# ..           ...       ...       ...       ...       ...        ...
# 329     0.856995  0.346286  0.015123  0.614851  0.576531        NaN
# 330     0.051369  0.673971  0.246242  0.435303  0.543259        NaN
# 331     0.089922  0.137640  0.367793  0.596974  0.940665        NaN
# 332     0.412241  0.730354  0.365914  0.444475  0.963139        NaN
# 333     0.507379  0.900381  0.298085  0.920676  0.715469        NaN
#
# [334 rows x 6 columns]

# %%
#newf=newf.drop(3,axis=1)

# %%
newf
# Out:
#                A         B         C         D         E          0
# 0     654.000000  0.844746  0.784994  0.411463  0.161811  2323444.0
# 1    1234.000000  0.863090  0.906042  0.095743  0.838045        NaN
# 2       0.170044  0.295632  0.110376  0.090735  0.868596        NaN
# 3       0.344054  0.172476  0.538477  0.322482  0.026525        NaN
# 4       0.807891  0.169485  0.310786  0.950250  0.877985        NaN
# ..           ...       ...       ...       ...       ...        ...
# 329     0.856995  0.346286  0.015123  0.614851  0.576531        NaN
# 330     0.051369  0.673971  0.246242  0.435303  0.543259        NaN
# 331     0.089922  0.137640  0.367793  0.596974  0.940665        NaN
# 332     0.412241  0.730354  0.365914  0.444475  0.963139        NaN
# 333     0.507379  0.900381  0.298085  0.920676  0.715469        NaN
#
# [334 rows x 6 columns]

# %%
newf.loc[[1,2],['C','D']] #IT WILL SHOW THE 1 AND 2 ROW'S C AND C COLUMN
# Out:
#           C         D
# 1  0.906042  0.095743
# 2  0.110376  0.090735

# %%
newf
# Out:
#                A         B         C         D         E          0
# 0     654.000000  0.844746  0.784994  0.411463  0.161811  2323444.0
# 1    1234.000000  0.863090  0.906042  0.095743  0.838045        NaN
# 2       0.170044  0.295632  0.110376  0.090735  0.868596        NaN
# 3       0.344054  0.172476  0.538477  0.322482  0.026525        NaN
# 4       0.807891  0.169485  0.310786  0.950250  0.877985        NaN
# ..           ...       ...       ...       ...       ...        ...
# 329     0.856995  0.346286  0.015123  0.614851  0.576531        NaN
# 330     0.051369  0.673971  0.246242  0.435303  0.543259        NaN
# 331     0.089922  0.137640  0.367793  0.596974  0.940665        NaN
# 332     0.412241  0.730354  0.365914  0.444475  0.963139        NaN
# 333     0.507379  0.900381  0.298085  0.920676  0.715469        NaN
#
# [334 rows x 6 columns]

# %%
newf.iloc[0,4] #it will print the value counting from 0 to 4 ,the value on 4th column here value on e column
# Out:
# 0.1618107941603536

# %%
newf.drop([0]) #it would delete tje whole row of 0th index
# Out:
#                A         B         C         D         E   0
# 1    1234.000000  0.863090  0.906042  0.095743  0.838045 NaN
# 2       0.170044  0.295632  0.110376  0.090735  0.868596 NaN
# 3       0.344054  0.172476  0.538477  0.322482  0.026525 NaN
# 4       0.807891  0.169485  0.310786  0.950250  0.877985 NaN
# 5       0.009332  0.228710  0.399589  0.864067  0.590843 NaN
# ..           ...       ...       ...       ...       ...  ..
# 329     0.856995  0.346286  0.015123  0.614851  0.576531 NaN
# 330     0.051369  0.673971  0.246242  0.435303  0.543259 NaN
# 331     0.089922  0.137640  0.367793  0.596974  0.940665 NaN
# 332     0.412241  0.730354  0.365914  0.444475  0.963139 NaN
# 333     0.507379  0.900381  0.298085  0.920676  0.715469 NaN
#
# [333 rows x 6 columns]

# %%
newf.drop(['A'],axis=1) #it would delete the whole a column
# Out:
#             B         C         D         E          0
# 0    0.844746  0.784994  0.411463  0.161811  2323444.0
# 1    0.863090  0.906042  0.095743  0.838045        NaN
# 2    0.295632  0.110376  0.090735  0.868596        NaN
# 3    0.172476  0.538477  0.322482  0.026525        NaN
# 4    0.169485  0.310786  0.950250  0.877985        NaN
# ..        ...       ...       ...       ...        ...
# 329  0.346286  0.015123  0.614851  0.576531        NaN
# 330  0.673971  0.246242  0.435303  0.543259        NaN
# 331  0.137640  0.367793  0.596974  0.940665        NaN
# 332  0.730354  0.365914  0.444475  0.963139        NaN
# 333  0.900381  0.298085  0.920676  0.715469        NaN
#
# [334 rows x 5 columns]

# %%
newf.drop(['A','C'],axis=1) #it would delete the whole A & C column
# Out:
#             B         D         E          0
# 0    0.844746  0.411463  0.161811  2323444.0
# 1    0.863090  0.095743  0.838045        NaN
# 2    0.295632  0.090735  0.868596        NaN
# 3    0.172476  0.322482  0.026525        NaN
# 4    0.169485  0.950250  0.877985        NaN
# ..        ...       ...       ...        ...
# 329  0.346286  0.614851  0.576531        NaN
# 330  0.673971  0.435303  0.543259        NaN
# 331  0.137640  0.596974  0.940665        NaN
# 332  0.730354  0.444475  0.963139        NaN
# 333  0.900381  0.920676  0.715469        NaN
#
# [334 rows x 4 columns]

# %%
newf
# Out:
#                A         B         C         D         E          0
# 0     654.000000  0.844746  0.784994  0.411463  0.161811  2323444.0
# 1    1234.000000  0.863090  0.906042  0.095743  0.838045        NaN
# 2       0.170044  0.295632  0.110376  0.090735  0.868596        NaN
# 3       0.344054  0.172476  0.538477  0.322482  0.026525        NaN
# 4       0.807891  0.169485  0.310786  0.950250  0.877985        NaN
# ..           ...       ...       ...       ...       ...        ...
# 329     0.856995  0.346286  0.015123  0.614851  0.576531        NaN
# 330     0.051369  0.673971  0.246242  0.435303  0.543259        NaN
# 331     0.089922  0.137640  0.367793  0.596974  0.940665        NaN
# 332     0.412241  0.730354  0.365914  0.444475  0.963139        NaN
# 333     0.507379  0.900381  0.298085  0.920676  0.715469        NaN
#
# [334 rows x 6 columns]

# %%
newf['D'].isnull() #it would return the columns in B where value is null
#where the value is true there it is null
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: D, Length: 334, dtype: bool

# %%
newf['B']=None # here now every value present in B column will become none

# %%
newf
# Out:
#                A     B         C         D         E          0
# 0     654.000000  None  0.784994  0.411463  0.161811  2323444.0
# 1    1234.000000  None  0.906042  0.095743  0.838045        NaN
# 2       0.170044  None  0.110376  0.090735  0.868596        NaN
# 3       0.344054  None  0.538477  0.322482  0.026525        NaN
# 4       0.807891  None  0.310786  0.950250  0.877985        NaN
# ..           ...   ...       ...       ...       ...        ...
# 329     0.856995  None  0.015123  0.614851  0.576531        NaN
# 330     0.051369  None  0.246242  0.435303  0.543259        NaN
# 331     0.089922  None  0.367793  0.596974  0.940665        NaN
# 332     0.412241  None  0.365914  0.444475  0.963139        NaN
# 333     0.507379  None  0.298085  0.920676  0.715469        NaN
#
# [334 rows x 6 columns]

# %%
newf['B'].isnull() #it would return true where value is true
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 329    True
# 330    True
# 331    True
# 332    True
# 333    True
# Name: B, Length: 334, dtype: bool

# %%
df
# Out:
#      name  marks      city
# 0    ashu    100    mohali
# 1     adi     99    mohali
# 2  arrush     98  dehradun
# 3  ruhani     33     solan
# 4  suhani     64     solan

# %%
f=pd.DataFrame=("name":["Alfred",'Batman','Catwomen'])
